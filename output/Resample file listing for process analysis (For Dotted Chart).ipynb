# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Dependencies-and-Import-Data" data-toc-modified-id="Import-Dependencies-and-Import-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Dependencies and Import Data</a></span></li><li><span><a href="#Create-New-Variables" data-toc-modified-id="Create-New-Variables-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create New Variables</a></span></li><li><span><a href="#Join-New-Dataframes-and-Export-to-Excel" data-toc-modified-id="Join-New-Dataframes-and-Export-to-Excel-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Join New Dataframes and Export to Excel</a></span></li></ul></div>

# %% [markdown]
# # Import Dependencies and Import Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_feather(f"filelist")

# %%
df.dtypes
# Out:
# Path                      object
# Directory                 object
# Name                      object
# CreationTime      datetime64[ns]
# LastAccessTime    datetime64[ns]
# LastWriteTime     datetime64[ns]
# Extension                 object
# BaseName                  object
# B                          int64
# dtype: object

# %%
#Random Rows https://stackoverflow.com/questions/15923826/random-row-selection-in-pandas-dataframe

no_rows = 100

df.loc[np.random.choice(df.index, no_rows)]
# Out:
#                                                      Path  \
# 91051   G:\IS\Plan_Services\AA_PDFs for clients (copie...
# 24486   G:\IS\Plan_Services\A_New Plans for TRIM\10 - ...
# 38723   G:\IS\Plan_Services\A - Rani to Check - (Engin...
# 9243    G:\IS\Plan_Services\A_New Plans for TRIM\zzz C...
# 24882   G:\IS\Plan_Services\A_New Plans for TRIM\10 - ...
# 105738  G:\IS\Plan_Services\AA_PDFs for clients (copie...
# 23379   G:\IS\Plan_Services\A_New Plans for TRIM\10 - ...
# 56458   G:\IS\Plan_Services\AA_PDFs for clients (copie...
# 67244   G:\IS\Plan_Services\AA_PDFs for clients (copie...
# 75725   G:\IS\Plan_Services\AA_PDFs for clients (copie...
# 10754   G:\IS\Plan_Services\A_New Plans for TRIM\5 - P...
# 32129   G:\IS\Plan_Services\zzz Nuala\Gosford Microgra...
# 31925   G:\IS\Plan_Services\zzz Nuala\Gosford Microgra...
# 13206   G:\IS\Plan_Services\A_New Plans for TRIM\5 - P...
# 16925   G:\IS\Plan_Services\A_New Plans for TRIM\10 - ...
# ...

# %% [markdown]
# # Create New Variables

# %%
df['ID'] = df.index

# %%
df_dm = df[['ID','LastWriteTime']]
df_dm.rename(columns={'LastWriteTime': 'TimeStart'}, inplace=True)
df_dm['Action'] = "LastWrite"
# Out:
# C:\Users\stewartc\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\Users\stewartc\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_dc = df[['ID','CreationTime']]
df_dc.rename(columns={'CreationTime': 'TimeStart'}, inplace=True)
df_dc['Action'] = "Create"
# Out:
# C:\Users\stewartc\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\Users\stewartc\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_da = df[['ID','LastAccessTime']]
df_da.rename(columns={'LastAccessTime': 'TimeStart'}, inplace=True)
df_da['Action'] = "LastAccess"
# Out:
# C:\Users\stewartc\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\Users\stewartc\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_dc.head()
# Out:
#    ID           TimeStart  Action
# 0   0 2018-03-15 16:04:43  Create
# 1   1 2017-03-20 17:29:05  Create
# 2   2 2016-08-04 13:52:29  Create
# 3   3 2017-03-05 09:47:35  Create
# 4   4 2017-05-12 11:18:32  Create

# %%
df_da.head()
# Out:
#    ID           TimeStart      Action
# 0   0 2018-11-05 09:34:20  LastAccess
# 1   1 2018-11-05 09:34:20  LastAccess
# 2   2 2018-11-05 09:34:20  LastAccess
# 3   3 2018-11-05 09:34:20  LastAccess
# 4   4 2018-11-05 09:34:20  LastAccess

# %%
df_dm.head()
# Out:
#    ID           TimeStart     Action
# 0   0 2018-03-15 16:04:43  LastWrite
# 1   1 2017-03-21 16:28:14  LastWrite
# 2   2 2016-08-04 13:52:29  LastWrite
# 3   3 2017-03-05 09:47:35  LastWrite
# 4   4 2017-05-12 11:18:32  LastWrite

# %% [markdown]
# # Join New Dataframes and Export to Excel

# %%
df_process = df_new = pd.concat([df_da, df_dc, df_dm])

# %%
df_process.head()
# Out:
#    ID           TimeStart      Action
# 0   0 2018-11-05 09:34:20  LastAccess
# 1   1 2018-11-05 09:34:20  LastAccess
# 2   2 2018-11-05 09:34:20  LastAccess
# 3   3 2018-11-05 09:34:20  LastAccess
# 4   4 2018-11-05 09:34:20  LastAccess

# %%
df_process.shape
# Out:
# (424944, 3)

# %%
df_process.to_csv('filelist_process.csv')
